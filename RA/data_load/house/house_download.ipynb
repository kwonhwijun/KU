# %% [markdown]
# end_point = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcSHTrade?_wadl&type=xml'
# encoding_key = 'ebl8Ut%2FJ2dsO84047u5ZUjBH53zpBM3YTtMLdGH0FkE6Ukn1z8Hy9WN45TvTQ%2BbdBRQctFDMT7GBZHqttCA8yg%3D%3D'

# %%
end_point = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcSHTrade?_wadl&type=xml'
encoding_key = 'ebl8Ut%2FJ2dsO84047u5ZUjBH53zpBM3YTtMLdGH0FkE6Ukn1z8Hy9WN45TvTQ%2BbdBRQctFDMT7GBZHqttCA8yg%3D%3D'
decoding_key = 'ebl8Ut/J2dsO84047u5ZUjBH53zpBM3YTtMLdGH0FkE6Ukn1z8Hy9WN45TvTQ+bdBRQctFDMT7GBZHqttCA8yg=='

# %%
'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcSHTradeex_url =f?LAWD_CD=11110&DEAL_YMD=201512&serviceKey={encoding_key}'

# %%
import requests
import xmltodict
import json
import pandas as pd

resp_xml = requests.get(ex_url)
resp_dict = xmltodict.parse(resp_xml.text)
dict = json.loads(json.dumps(resp_dict))
item_dict  = dict.get('response', {}).get('body', {}).get('items')
pd.DataFrame(item_dict['item'])
# Out:
#        거래금액  거래유형  건축년도     년    대지면적   매도자   매수자   법정동     연면적   월   일 주택유형  \
# 0    86,000  None  1955  2015    66.1  None  None   누하동   39.67  12  28   단독
# 1    38,500  None  1985  2015    62.8  None  None   옥인동   37.26  12  17   단독
# 2   118,000  None  1991  2015    92.6  None  None   체부동  206.01  12  31   단독
# 3    81,000  None  1900  2015   145.5  None  None   필운동   79.34  12   4   단독
# 4   210,000  None  1997  2015    88.2  None  None   필운동  297.16  12  23   단독
# 5   220,000  None  1994  2015   202.6  None  None   운니동  411.81  12   9  다가구
# 6    59,900  None  1900  2015    62.8  None  None   익선동   30.68  12  16   단독
# 7   110,000  None  1900  2015    72.7  None  None   팔판동   79.57  12   1   단독
# 8    98,300  None  1970  2015    73.7  None  None   삼청동  124.89  12  30   단독
# 9    63,000  None  1900  2015    69.4  None  None    묘동   34.05  12   1   단독
# 10   90,000  None  1987  2015     163  None  None   이화동  247.75  12   8   단독
# ...
