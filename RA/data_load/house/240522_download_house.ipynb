# %%
import api

# %%
api.make_url(11110, 202211)
# Out:
# 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey=ebl8Ut%2FJ2dsO84047u5ZUjBH53zpBM3YTtMLdGH0FkE6Ukn1z8Hy9WN45TvTQ%2BbdBRQctFDMT7GBZHqttCA8yg%3D%3D&pageNo=1&numOfRows=2000&LAWD_CD=11110&DEAL_YMD=202211'

# %%
api.save_data()

# %%
api.get_df(11110,202211)
# Out:
#       거래금액  거래유형  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드  \
# 0   65,000  중개거래  1998  2022  삼일대로32길      00036      00000    11110
# 1   18,600  중개거래  2014  2022      대학로      00047      00000    11110
# 2   15,300  중개거래  2011  2022   율곡로20길      00024      00000    11110
# 3   35,000  중개거래  1999  2022    동숭4라길      00029      00000    11110
# 4   90,000  중개거래  1996  2022    혜화로3길      00033      00000    11110
# 5   90,000  중개거래  1996  2022    혜화로3길      00033      00000    11110
# 6   90,000  중개거래  1996  2022    혜화로3길      00033      00000    11110
# 7   90,000  중개거래  1996  2022    혜화로3길      00033      00000    11110
# 8   59,500  중개거래  1993  2022      낙산길      00198      00000    11110
# 9   12,900  중개거래  2013  2022    종로66길      00028      00000    11110
# 10  12,000  중개거래  2013  2022  난계로29가길      00019      00000    11110
#
#    도로명일련번호코드 도로명지상지하코드  ...   월   일        일련번호    전용면적   중개사소재지      지번  \
# ...
