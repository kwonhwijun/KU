# %%
import requests
import json
import pandas as pd 
import api
import xmltodict
global key_dict
base_url= api.make_url(11110, 202306, 1)

try:
    res = requests.get(base_url)
    data = json.loads(json.dumps(xmltodict.parse(res.text)))
    
    # items가 None이거나 'item' 키가 없는 경우를 처리
    items = data.get('response', {}).get('body', {}).get('items', None)
    if items is None or 'item' not in items:
        print("No data available or incorrect data structure.")
    
    df = pd.DataFrame(items['item'])


except KeyError as e:
    print(f"KeyError - reason: {str(e)}")

except TypeError as e:
    print(f"TypeError - reason: {str(e)}")

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# No data available or incorrect data structure.
# TypeError - reason: 'NoneType' object is not subscriptable

# %%
import api

api.save_data()
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '138,000',
#       '거래유형': '중개거래',
#       '건축년도': '2008',
#       '년': '2023',
#       '도로명': '사직로8길',
#       '도로명건물본번호코드': '00004',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '03',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100135',
#       '동': '101',
#       '등기일자': '23.07.31',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '사직동',
#       '법정동본번코드': '0009',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '11500',
#       '법정동지번코드': '1',
#       '아파트': '광화문스페이스본(101동~105동)',
#       '월': '6',
#       '일': '9',
#       '일련번호': '11110-2203',
#       '전용면적': '95.88',
#       '중개사소재지': '서울 종로구',
#       '지번': '9',
#       '지역코드': '11110',
#       '층': '9',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '170,000',
#       '거래유형': '중개거래',
#       '건축년도': '2008',
#       '년': '2023',
#       '도로명': '사직로8길',
#       '도로명건물본번호코드': '00004',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '03',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100135',
#       '동': '104',
#       '등기일자': '23.08.03',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '사직동',
#       '법정동본번코드': '0009',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '11500',
#       '법정동지번코드': '1',
#       '아파트': '광화문스페이스본(101동~105동)',
#       '월': '6',
#       '일': '10',
#       '일련번호': '11110-2203',
#       '전용면적': '146.92',
#       '중개사소재지': '서울 종로구',
#       '지번': '9',
#       '지역코드': '11110',
#       '층': '8',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '84,000',
#       '거래유형': '직거래',
#       '건축년도': '1970',
#       '년': '2023',
#       '도로명': '사직로9길',
#       '도로명건물본번호코드': '00014',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '02',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100137',
#       '동': None,
#       '등기일자': '23.07.19',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '사직동',
#       '법정동본번코드': '0001',
#       '법정동부번코드': '0008',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '11500',
#       '법정동지번코드': '1',
#       '아파트': '사직아파트',
#       '월': '6',
#       '일': '12',
#       '일련번호': '11110-2109',
#       '전용면적': '116.23',
#       '중개사소재지': None,
#       '지번': '1-8',
#       '지역코드': '11110',
#       '층': '6',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '93,000',
#       '거래유형': '중개거래',
#       '건축년도': '1981',
#       '년': '2023',
#       '도로명': '세종대로23길',
#       '도로명건물본번호코드': '00047',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '02',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100190',
#       '동': None,
#       '등기일자': '24.02.29',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '당주동',
#       '법정동본번코드': '0145',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '11700',
#       '법정동지번코드': '1',
#       '아파트': '롯데미도파광화문빌딩',
#       '월': '6',
#       '일': '20',
#       '일련번호': '11110-12',
#       '전용면적': '149.95',
#       '중개사소재지': '서울 종로구',
#       '지번': '145',
#       '지역코드': '11110',
#       '층': '9',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '408,000',
#       '거래유형': '중개거래',
#       '건축년도': '2020',
#       '년': '2023',
#       '도로명': '새문안로2길',
#       '도로명건물본번호코드': '00010',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100157',
#       '동': None,
#       '등기일자': '23.10.13',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '신문로2가',
#       '법정동본번코드': '0171',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '12100',
#       '법정동지번코드': '1',
#       '아파트': '디팰리스',
#       '월': '6',
#       '일': '24',
#       '일련번호': '11110-2539',
#       '전용면적': '148.111',
#       '중개사소재지': '서울 강남구, 서울 종로구',
#       '지번': '171',
#       '지역코드': '11110',
#       '층': '10',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '64,500',
#       '거래유형': '중개거래',
#       '건축년도': '1998',
#       '년': '2023',
#       '도로명': '삼일대로32길',
#       '도로명건물본번호코드': '00036',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '02',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100147',
#       '동': '운현신화타워',
#       '등기일자': '23.09.21',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '익선동',
#       '법정동본번코드': '0030',
#       '법정동부번코드': '0006',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '13300',
#       '법정동지번코드': '1',
#       '아파트': '운현신화타워',
#       '월': '6',
#       '일': '24',
#       '일련번호': '11110-16',
#       '전용면적': '50.31',
#       '중개사소재지': '서울 종로구',
#       '지번': '30-6',
#       '지역코드': '11110',
#       '층': '14',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '40,000',
#       '거래유형': '중개거래',
#       '건축년도': '2003',
#       '년': '2023',
#       '도로명': '돈화문로11가길',
#       '도로명건물본번호코드': '00059',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '03',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100050',
#       '동': '현대뜨레비앙',
#       '등기일자': '23.08.14',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '익선동',
#       '법정동본번코드': '0055',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '13300',
#       '법정동지번코드': '1',
#       '아파트': '현대뜨레비앙',
#       '월': '6',
#       '일': '27',
#       '일련번호': '11110-102',
#       '전용면적': '46.64',
#       '중개사소재지': '서울 종로구',
#       '지번': '55',
#       '지역코드': '11110',
#       '층': '3',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '17,300',
#       '거래유형': '중개거래',
#       '건축년도': '2017',
#       '년': '2023',
#       '도로명': '대학로',
#       '도로명건물본번호코드': '00033',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3100002',
#       '동': '포레스트힐시티',
#       '등기일자': '23.07.21',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '효제동',
#       '법정동본번코드': '0065',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '16200',
#       '법정동지번코드': '1',
#       '아파트': '포레스트힐시티',
#       '월': '6',
#       '일': '6',
#       '일련번호': '11110-2440',
#       '전용면적': '15.879',
#       '중개사소재지': '서울 종로구',
#       '지번': '65-2',
#       '지역코드': '11110',
#       '층': '5',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '15,400',
#       '거래유형': '중개거래',
#       '건축년도': '2011',
#       '년': '2023',
#       '도로명': '율곡로20길',
#       '도로명건물본번호코드': '00024',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100225',
#       '동': 'CS타워',
#       '등기일자': '23.07.07',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '충신동',
#       '법정동본번코드': '0062',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '16700',
#       '법정동지번코드': '1',
#       '아파트': 'CS타워',
#       '월': '6',
#       '일': '22',
#       '일련번호': '11110-2291',
#       '전용면적': '22.17',
#       '중개사소재지': '서울 종로구',
#       '지번': '62-2',
#       '지역코드': '11110',
#       '층': '5',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '60,000',
#       '거래유형': '중개거래',
#       '건축년도': '2006',
#       '년': '2023',
#       '도로명': '혜화로3가길',
#       '도로명건물본번호코드': '00030',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100544',
#       '동': None,
#       '등기일자': '23.09.25',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '명륜1가',
#       '법정동본번코드': '0019',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17000',
#       '법정동지번코드': '1',
#       '아파트': '렉스빌',
#       '월': '6',
#       '일': '25',
#       '일련번호': '11110-973',
#       '전용면적': '80.5',
#       '중개사소재지': '서울 종로구',
#       '지번': '19',
#       '지역코드': '11110',
#       '층': '6',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '136,000',
#       '거래유형': '중개거래',
#       '건축년도': '1996',
#       '년': '2023',
#       '도로명': '혜화로3길',
#       '도로명건물본번호코드': '00033',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '02',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100545',
#       '동': '201',
#       '등기일자': '23.06.20',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '명륜2가',
#       '법정동본번코드': '0236',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17100',
#       '법정동지번코드': '1',
#       '아파트': '아남2',
#       '월': '6',
#       '일': '14',
#       '일련번호': '11110-92',
#       '전용면적': '114.36',
#       '중개사소재지': '서울 종로구',
#       '지번': '236',
#       '지역코드': '11110',
#       '층': '7',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '12,000',
#       '거래유형': '직거래',
#       '건축년도': '2014',
#       '년': '2023',
#       '도로명': '난계로29가길',
#       '도로명건물본번호코드': '00020',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100029',
#       '동': None,
#       '등기일자': '23.06.15',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '숭인동',
#       '법정동본번코드': '1421',
#       '법정동부번코드': '0002',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17500',
#       '법정동지번코드': '1',
#       '아파트': '숭인한양LEEPS',
#       '월': '6',
#       '일': '1',
#       '일련번호': '11110-2366',
#       '전용면적': '12.78',
#       '중개사소재지': None,
#       '지번': '1421-2',
#       '지역코드': '11110',
#       '층': '11',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '120,000',
#       '거래유형': '중개거래',
#       '건축년도': '2004',
#       '년': '2023',
#       '도로명': '종로',
#       '도로명건물본번호코드': '00347',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '14',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3100013',
#       '동': '롯데캐슬 천지인(천)',
#       '등기일자': '23.07.27',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '숭인동',
#       '법정동본번코드': '0076',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17500',
#       '법정동지번코드': '1',
#       '아파트': '롯데캐슬천지인',
#       '월': '6',
#       '일': '24',
#       '일련번호': '11110-152',
#       '전용면적': '111.73',
#       '중개사소재지': '서울 성북구, 서울 종로구',
#       '지번': '76',
#       '지역코드': '11110',
#       '층': '28',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '65,000',
#       '거래유형': '중개거래',
#       '건축년도': '1979',
#       '년': '2023',
#       '도로명': '청계천로',
#       '도로명건물본번호코드': '00391',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '08',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3100021',
#       '동': None,
#       '등기일자': '23.11.14',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '숭인동',
#       '법정동본번코드': '0204',
#       '법정동부번코드': '0011',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17500',
#       '법정동지번코드': '1',
#       '아파트': '숭인상가',
#       '월': '6',
#       '일': '27',
#       '일련번호': '11110-48',
#       '전용면적': '78.75',
#       '중개사소재지': '서울 중구',
#       '지번': '204-11',
#       '지역코드': '11110',
#       '층': '7',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '280,000',
#       '거래유형': '중개거래',
#       '건축년도': '2017',
#       '년': '2023',
#       '도로명': '경교장길',
#       '도로명건물본번호코드': '00035',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명코드': '4100002',
#       '동': '304',
#       '등기일자': '23.07.21',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '평동',
#       '법정동본번코드': '0233',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17700',
#       '법정동지번코드': '1',
#       '아파트': '경희궁자이(3단지)',
#       '월': '6',
#       '일': '22',
#       '일련번호': '11110-2446',
#       '전용면적': '116.9383',
#       '중개사소재지': '서울 용산구',
#       '지번': '233',
#       '지역코드': '11110',
#       '층': '9',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '188,000',
#       '거래유형': '중개거래',
#       '건축년도': '2017',
#       '년': '2023',
#       '도로명': '송월길',
#       '도로명건물본번호코드': '00099',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명코드': '4100192',
#       '동': '203',
#       '등기일자': '23.09.01',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '홍파동',
#       '법정동본번코드': '0199',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17900',
#       '법정동지번코드': '1',
#       '아파트': '경희궁자이(2단지)',
#       '월': '6',
#       '일': '8',
#       '일련번호': '11110-2445',
#       '전용면적': '84.9443',
#       '중개사소재지': '서울 종로구',
#       '지번': '199',
#       '지역코드': '11110',
#       '층': '14',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '270,000',
#       '거래유형': '중개거래',
#       '건축년도': '2017',
#       '년': '2023',
#       '도로명': '송월길',
#       '도로명건물본번호코드': '00099',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명코드': '4100192',
#       '동': '207',
#       '등기일자': '23.09.27',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '홍파동',
#       '법정동본번코드': '0199',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17900',
#       '법정동지번코드': '1',
#       '아파트': '경희궁자이(2단지)',
#       '월': '6',
#       '일': '14',
#       '일련번호': '11110-2445',
#       '전용면적': '116.9862',
#       '중개사소재지': '서울 종로구',
#       '지번': '199',
#       '지역코드': '11110',
#       '층': '20',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '182,500',
#       '거래유형': '중개거래',
#       '건축년도': '2017',
#       '년': '2023',
#       '도로명': '송월길',
#       '도로명건물본번호코드': '00099',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명코드': '4100192',
#       '동': '201',
#       '등기일자': '23.08.31',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '홍파동',
#       '법정동본번코드': '0199',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '17900',
#       '법정동지번코드': '1',
#       '아파트': '경희궁자이(2단지)',
#       '월': '6',
#       '일': '22',
#       '일련번호': '11110-2445',
#       '전용면적': '84.8359',
#       '중개사소재지': '서울 종로구',
#       '지번': '199',
#       '지역코드': '11110',
#       '층': '10',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '56,000',
#       '거래유형': '중개거래',
#       '건축년도': '2019',
#       '년': '2023',
#       '도로명': '비봉길',
#       '도로명건물본번호코드': '00007',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100122',
#       '동': None,
#       '등기일자': '23.07.31',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '구기동',
#       '법정동본번코드': '0125',
#       '법정동부번코드': '0005',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18200',
#       '법정동지번코드': '1',
#       '아파트': '마운틴뷰',
#       '월': '6',
#       '일': '6',
#       '일련번호': '11110-2502',
#       '전용면적': '76.66',
#       '중개사소재지': '서울 종로구',
#       '지번': '125-5',
#       '지역코드': '11110',
#       '층': '1',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '116,500',
#       '거래유형': '중개거래',
#       '건축년도': '2019',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00230',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '101동',
#       '등기일자': '23.08.10',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0089',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '경희궁롯데캐슬',
#       '월': '6',
#       '일': '5',
#       '일련번호': '11110-2519',
#       '전용면적': '59.6737',
#       '중개사소재지': '서울 서대문구, 서울 종로구',
#       '지번': '89',
#       '지역코드': '11110',
#       '층': '4',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '114,000',
#       '거래유형': '중개거래',
#       '건축년도': '2019',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00230',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '101동',
#       '등기일자': '23.06.19',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0089',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '경희궁롯데캐슬',
#       '월': '6',
#       '일': '7',
#       '일련번호': '11110-2519',
#       '전용면적': '59.6737',
#       '중개사소재지': '서울 종로구',
#       '지번': '89',
#       '지역코드': '11110',
#       '층': '2',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '125,900',
#       '거래유형': '중개거래',
#       '건축년도': '2000',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00246',
#       '도로명건물부번호코드': '00020',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '06',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '109',
#       '등기일자': '23.08.29',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0082',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '현대',
#       '월': '6',
#       '일': '9',
#       '일련번호': '11110-90',
#       '전용면적': '114.9',
#       '중개사소재지': '서울 종로구',
#       '지번': '82',
#       '지역코드': '11110',
#       '층': '3',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '130,000',
#       '거래유형': '중개거래',
#       '건축년도': '2008',
#       '년': '2023',
#       '도로명': '통일로18길',
#       '도로명건물본번호코드': '00009',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100482',
#       '동': '103',
#       '등기일자': '23.07.27',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0060',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '인왕산아이파크',
#       '월': '6',
#       '일': '10',
#       '일련번호': '11110-2212',
#       '전용면적': '84.858',
#       '중개사소재지': '서울 종로구',
#       '지번': '60',
#       '지역코드': '11110',
#       '층': '15',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '158,000',
#       '거래유형': '중개거래',
#       '건축년도': '2008',
#       '년': '2023',
#       '도로명': '통일로18길',
#       '도로명건물본번호코드': '00009',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100482',
#       '동': '105',
#       '등기일자': '23.07.27',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0060',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '인왕산아이파크',
#       '월': '6',
#       '일': '10',
#       '일련번호': '11110-2212',
#       '전용면적': '114.931',
#       '중개사소재지': '서울 종로구',
#       '지번': '60',
#       '지역코드': '11110',
#       '층': '10',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '141,000',
#       '거래유형': '중개거래',
#       '건축년도': '2019',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00230',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '00',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '104동',
#       '등기일자': '23.08.28',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0089',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '경희궁롯데캐슬',
#       '월': '6',
#       '일': '14',
#       '일련번호': '11110-2519',
#       '전용면적': '84.8792',
#       '중개사소재지': '서울 종로구',
#       '지번': '89',
#       '지역코드': '11110',
#       '층': '8',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '79,900',
#       '거래유형': '중개거래',
#       '건축년도': '2000',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00246',
#       '도로명건물부번호코드': '00020',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '06',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '103',
#       '등기일자': '23.10.05',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0082',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '현대',
#       '월': '6',
#       '일': '19',
#       '일련번호': '11110-90',
#       '전용면적': '60',
#       '중개사소재지': '서울 종로구',
#       '지번': '82',
#       '지역코드': '11110',
#       '층': '3',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '108,900',
#       '거래유형': '중개거래',
#       '건축년도': '2000',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00246',
#       '도로명건물부번호코드': '00020',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '06',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '110',
#       '등기일자': '23.10.05',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0082',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '현대',
#       '월': '6',
#       '일': '19',
#       '일련번호': '11110-90',
#       '전용면적': '84.92',
#       '중개사소재지': '서울 종로구',
#       '지번': '82',
#       '지역코드': '11110',
#       '층': '5',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '142,000',
#       '거래유형': '중개거래',
#       '건축년도': '2000',
#       '년': '2023',
#       '도로명': '통일로',
#       '도로명건물본번호코드': '00246',
#       '도로명건물부번호코드': '00020',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '06',
#       '도로명지상지하코드': '0',
#       '도로명코드': '3000008',
#       '동': '109',
#       '등기일자': '23.09.19',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0082',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '현대',
#       '월': '6',
#       '일': '20',
#       '일련번호': '11110-90',
#       '전용면적': '114.9',
#       '중개사소재지': '서울 종로구',
#       '지번': '82',
#       '지역코드': '11110',
#       '층': '17',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '115,500',
#       '거래유형': '중개거래',
#       '건축년도': '2015',
#       '년': '2023',
#       '도로명': '통일로18길',
#       '도로명건물본번호코드': '00034',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100482',
#       '동': '203',
#       '등기일자': '23.09.14',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0088',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '인왕산2차아이파크',
#       '월': '6',
#       '일': '24',
#       '일련번호': '11110-2417',
#       '전용면적': '84.2395',
#       '중개사소재지': '서울 종로구',
#       '지번': '88',
#       '지역코드': '11110',
#       '층': '6',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '129,500',
#       '거래유형': '중개거래',
#       '건축년도': '2008',
#       '년': '2023',
#       '도로명': '통일로18길',
#       '도로명건물본번호코드': '00009',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11110',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4100482',
#       '동': '101',
#       '등기일자': '23.10.30',
#       '매도자': None,
#       '매수자': None,
#       '법정동': '무악동',
#       '법정동본번코드': '0060',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11110',
#       '법정동읍면동코드': '18700',
#       '법정동지번코드': '1',
#       '아파트': '인왕산아이파크',
#       '월': '6',
#       '일': '30',
#       '일련번호': '11110-2212',
#       '전용면적': '84.858',
#       '중개사소재지': '서울 서초구, 서울 종로구',
#       '지번': '60',
#       '지역코드': '11110',
#       '층': '7',
#       '해제사유발생일': None,
#       '해제여부': None}]},
#    'numOfRows': '2000',
#    'pageNo': '1',
#    'totalCount': '30'}}}

# %%
data.get('response', {}).get('header')
# Out:
# {'resultCode': '99',
#  'resultMsg': 'LIMITED NUMBER OF SERVICE REQUESTS EXCEEDS ERROR.'}
