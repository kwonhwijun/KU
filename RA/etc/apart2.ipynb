# %%
import requests
import xmltodict
import pandas as pd
import requests
import json

# %%
from sqlalchemy import create_engine

engine_apt_2 = create_engine('sqlite:///apt_trade_2.db')

# %%
import api
loc_seoul = api.loc_code('seoul') #25개
loc_all = api.loc_code('all') #477개

ym_21_24 = api.create_ym_list(2021,2024) #60
ym_11_20 = api.create_ym_list(2011,2020) #120
ym_06_10 = api.create_ym_list(2006,2010) #48

# %% [markdown]
# 2006년 ~ 2024년 : 228개월
# 전국 지역구 코드 : 477개
#
# 228 * 477 = 10만 8756개
#
#
# # 서울

# %%
api.save_all(engine_apt_2, loc_seoul, ym_21_24, 2) #25*36 =
# Out:
# 202101 data is saved
# 202102 data is saved
# 202103 data is saved
# 202104 data is saved
# No data available or incorrect data structure.
# No data is saved in loc_code : 11410
# 202105 data is saved
# 202106 data is saved
# 202107 data is saved
# 202108 data is saved
# 202109 data is saved
# 202110 data is saved
# 202111 data is saved
# 202112 data is saved
# 202201 data is saved
# 202202 data is saved
# 202203 data is saved
# 202204 data is saved
# 202205 data is saved
# 202206 data is saved
# 202207 data is saved
# 202208 data is saved
# 202209 data is saved
# 202210 data is saved
# 202211 data is saved
# 202212 data is saved
# 202301 data is saved
# 202302 data is saved
# 202303 data is saved
# 202304 data is saved
# 202305 data is saved
# 202306 data is saved
# 202307 data is saved
# 202308 data is saved
# 202309 data is saved
# 202310 data is saved
# 202311 data is saved
# 202312 data is saved
# 202401 data is saved
# 202402 data is saved
# 202403 data is saved
# ...

# %%
import db
db.db2excel(engine_apt_2,"apt_trades_detail", "data/apt_21_24_2")
