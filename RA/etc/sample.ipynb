# %%
import pandas as pd

df1 = pd.read_csv('test1.txt') #소비 및 이동 
df2 = pd.read_csv('test2.txt') #금융 생활
print(df1.columns) # 1000 x 102
print(df2.columns) # 1000 * 65
# Out:
# Index(['자치구명', '생년월일', '성별', '동일세대_학령기인구수', '동일세대_미취학아동수', '직업군', '평균_문자대상자수',
#        '평균_통화대상자수', '평균_통화량', '세대주여부',
#        ...
#        '3개월내_탑승정류장수', '평일_이동_총횟수', '휴일_이동_총횟수', '평일_총이동거리', '평일_이동속도_평균',
#        '휴일_총이동거리', '휴일_이동속도_평균', '택시이용_이동횟수', '네비게이션이용_이동횟수', '지하철_이동일수'],
#       dtype='object', length=102)
# Index(['자치구명', '생년월일', '성별', '동일세대_학령기인구수', '동일세대_미취학아동수', '직업군', '세대주여부',
#        '1인가구여부', '주택보유여부', '대출여부', '연체여부', '사업자여부', '동일세대_세대원_수', '추정연소득',
#        '추정연소득_백분위', '총자산평가금액', '순자산평가금액', '차량보유', '주택보유건수', '자가거주여부',
#        '주택보유건수_가구기준', '자가거주여부_가구기준', '총대출약정금액', '총대출건수', '총대출잔액', '은행업종대출잔액',
#        '주택담보대출잔액', '신용대출잔액', '자동차대출잔액', 'LTV', '가구단위_LTV', '연체건수', '연체금액',
#        '연체일수', '주택담보대출분기상환금액', '카드소비금액', '신용카드소비금액', '체크카드소비금액', '일시불이용금액',
#        '할부이용금액', '현금서비스이용금액', '해외카드이용금액', '생애최초주택구입연월', '카드사_최근1년월평균_이용금액',
#        '온라인 카드사용 금액', '오프라인 카드사용 금액', '온라인_카드사용금액_백분위수', '오프라인_카드사용금액_백분위수',
# ...

# %%
df1["자치구명"].value_counts()
# Out:
# 자치구명
# 강서구     72
# 송파구     66
# 강동구     59
# 구로구     55
# 은평구     52
# 성북구     50
# 노원구     46
# 강남구     46
# 서초구     44
# 서대문구    44
# 양천구     44
# 관악구     43
# 중랑구     43
# 동대문구    40
# 마포구     40
# 동작구     40
# 영등포구    34
# 도봉구     33
# 강북구     33
# 성동구     25
# 중구      24
# 용산구     24
# 광진구     19
# 금천구     16
# 종로구      8
# Name: count, dtype: int64
